# %% [markdown]
# <a href="https://colab.research.google.com/github/BeData-id/app-store-scrap/blob/main/scrap_app_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install app-store-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 883.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ...

# %%
from app_store_scraper import AppStore
from pprint import pprint

foo = AppStore(country="kr", app_name="Line")
foo.review(how_many=20)

pprint(foo.reviews)
pprint(foo.reviews_count)
# Out:
# [{'date': datetime.datetime(2017, 12, 19, 12, 14, 47),
#   'isEdited': False,
#   'rating': 3,
#   'review': '관리자님 항상 고생 많으십니다!😊 라인 아주 잘 쓰고 있는데요, 몇가지 문제점이 있어 리뷰 남깁니다.\n'
#             '우선은 라인 알림이 바로 안오고 짧으면 2~5분, 길면 아예 안와요ㅠㅠ 이유를 잘 모르겠습니다. 제 핸드폰 기종은 '
#             '아이폰7+입니다.\n'
#             '그리고 사진 전송할 때 화질 조금만 개선해주세요!!\n'
#             '마지막으로 라인에도 동영상 모아보기 기능이 있었으면 좋겠습니다. 사진은 모아볼 수 있는데 동영상은 그렇지 않아서 많이 '
#             '불편하더라구요ㅠㅠ\n'
#             '문제점들 고쳐주시면 너무 감사할거 같습니다!',
#   'title': '라인 몇가지 문제ㅜ',
#   'userName': '알림.. 제발..'},
#  {'date': datetime.datetime(2021, 2, 16, 21, 57, 2),
#   'isEdited': False,
#   'rating': 5,
#   'review': '오랜만에 라인을 다시 깔고서 해시태그 기능이 사라진 것을 알게 되었습니다. 친구신청 기능이 사라진지 꽤 오래됐다는 '
#             '것은 이전부터 알고 있었습니다. 해시태그 기능은 각종 커뮤니티를 거치지 않고 오직 라인만으로 새로운 사람들을 만날 수 '
#             '있는 간편한 기능이었다고 생각합니다. 친구신청 기능은 모르는 사람에게서 신청이 왔을 경우 쉽게 거절할 수 있다는 점, '
#             '반대로 별다른 QR코드나 아이디 없이 추가하고 수락할 수 있다는 점을 장점이라 할 수 있습니다. 해시태그 기능과 '
# ...

# %%
import pandas as pd

df = pd.DataFrame(foo.reviews)
df
# Out:
#                   date                                             review  \
# 0  2017-12-19 12:14:47  관리자님 항상 고생 많으십니다!😊 라인 아주 잘 쓰고 있는데요, 몇가지 문제점이 있...
# 1  2021-02-16 21:57:02  오랜만에 라인을 다시 깔고서 해시태그 기능이 사라진 것을 알게 되었습니다. 친구신청...
# 2  2021-02-15 17:21:41  잘만 사용 중이었고 태그로 글 정리된 거 한 번에 볼 수 있어서 애용했는데 없어졌네...
# 3  2020-07-14 12:30:53  일단 별 다섯개 주기는 주는데 친신기능 왜 없앴는지 궁금하네요 링크는 댓글이나 글에...
# 4  2020-02-03 01:16:05  안녕하세요 라인앱을 6년동안 사용하고 있는 유저입니다 라인 업뎃 이후에 타임라인에 ...
# 5  2021-12-01 04:09:31  알람이 와서 들어가보면 내용이 뜨는데 딜레이가 있네요..쪼금 불편하네요 아이폰이라서...
# 6  2018-12-22 08:06:06  이제 육 년째 쓰고 있는 사용자입니다. 이번 업데이트를 통해 타임라인 해시태그를 누...
# 7  2021-01-26 16:14:40  why 해시태그 안 들어가지나요? 처음에는 my cell phone 문제인 줄 알았...
# 8  2019-01-22 22:00:32  전여친과 카톡 보다 더 애용 하던 앱인데 몇 년 후인 지금도  들어가기만 하면 추억...
# 9  2022-04-11 08:51:21  잘 쓰고 있다가 한동안 안해서 지웠는데 다시 깔아서 로그인 하는데 인증번호 전송 화...
# 10 2017-10-27 01:09:05  테마 사서 적용하면 시작 화면도 다 바뀌는데 라인 켰을 때 보이는 최초의 페이지가 ...
# 11 2021-12-02 08:07:50  처음으로 어플 평가를 해봅니다. 평가를 하는 이유는, 제가 매일 라인 어플을 사용하...
# ...

# %%
df.to_csv('line.csv', header=True, index=False)
